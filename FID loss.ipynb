# %% [markdown]
# <a href="https://colab.research.google.com/github/Stanfording/Trying_FID_LOSS/blob/main/FID%20loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Goal:   Testing if FID Loss works on training GAN

# %% [markdown]
# ### Get the preprocessed celebHD data from google drive

# %%
#Download the dataset
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1KqBRLsB0CJuQGycvaPINwaPgcGDUsAxN' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1KqBRLsB0CJuQGycvaPINwaPgcGDUsAxN" -O "proCeleba.zip" && rm -rf /tmp/cookies.txt

#unzip the dataset
# !unzip "/content/proCeleba.zip"

#remove unnecessary files
# !rm -rf /content/__MACOSX
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: proCeleba/64/152521.jpg
#   inflating: proCeleba/64/059306.jpg
#   inflating: proCeleba/64/000273.jpg
#   inflating: proCeleba/64/199136.jpg
#   inflating: proCeleba/64/181779.jpg
#   inflating: proCeleba/64/089457.jpg
#   inflating: proCeleba/64/096577.jpg
#   inflating: proCeleba/64/131904.jpg
#   inflating: proCeleba/64/054622.jpg
#   inflating: proCeleba/64/080315.jpg
#   inflating: proCeleba/64/088749.jpg
#   inflating: proCeleba/64/160593.jpg
#   inflating: proCeleba/64/194374.jpg
#   inflating: proCeleba/64/151996.jpg
#   inflating: proCeleba/64/002302.jpg
#   inflating: proCeleba/64/170780.jpg
#   inflating: proCeleba/64/100267.jpg
#   inflating: proCeleba/64/146232.jpg
#   inflating: proCeleba/64/110074.jpg
#   inflating: proCeleba/64/159312.jpg
#   inflating: proCeleba/64/045049.jpg
#   inflating: proCeleba/64/142054.jpg
#   inflating: proCeleba/64/049673.jpg
#   inflating: proCeleba/64/155528.jpg
#   inflating: proCeleba/64/114212.jpg
#   inflating: proCeleba/64/028299.jpg
#   inflating: proCeleba/64/040131.jpg
#   inflating: proCeleba/64/190112.jpg
#   inflating: proCeleba/64/084615.jpg
#   inflating: proCeleba/64/077951.jpg
#   inflating: proCeleba/64/049667.jpg
#   inflating: proCeleba/64/059474.jpg
#   inflating: proCeleba/64/115118.jpg
#   inflating: proCeleba/64/144431.jpg
#   inflating: proCeleba/64/019050.jpg
#   inflating: proCeleba/64/138934.jpg
#   inflating: proCeleba/64/012105.jpg
#   inflating: proCeleba/64/098228.jpg
#   inflating: proCeleba/64/192711.jpg
#   inflating: proCeleba/64/096205.jpg
#   inflating: proCeleba/64/099136.jpg
#   inflating: proCeleba/64/052521.jpg
#   inflating: proCeleba/64/159306.jpg
#   inflating: proCeleba/64/089325.jpg
#   inflating: proCeleba/64/063924.jpg
#   inflating: proCeleba/64/052247.jpg
#   inflating: proCeleba/64/014212.jpg
#   inflating: proCeleba/64/159460.jpg
#   inflating: proCeleba/64/119044.jpg
#   inflating: proCeleba/64/033875.jpg
#   inflating: proCeleba/64/044425.jpg
#   inflating: proCeleba/64/009525.jpg
#   inflating: proCeleba/64/102302.jpg
#   inflating: proCeleba/64/152535.jpg
#   inflating: proCeleba/64/189331.jpg
#   inflating: proCeleba/64/000267.jpg
#   inflating: proCeleba/64/045713.jpg
#   inflating: proCeleba/64/099678.jpg
#   inflating: proCeleba/64/148545.jpg
#   inflating: proCeleba/64/168695.jpg
#   inflating: proCeleba/64/166860.jpg
#   inflating: proCeleba/64/198214.jpg
#   inflating: proCeleba/64/112139.jpg
#   inflating: proCeleba/64/058024.jpg
#   inflating: proCeleba/64/056009.jpg
#   inflating: proCeleba/64/051766.jpg
#   inflating: proCeleba/64/017733.jpg
#   inflating: proCeleba/64/122944.jpg
#   inflating: proCeleba/64/142068.jpg
#   inflating: proCeleba/64/006158.jpg
#   inflating: proCeleba/64/083146.jpg
#   inflating: proCeleba/64/084629.jpg
#   inflating: proCeleba/64/001637.jpg
#   inflating: proCeleba/64/079954.jpg
#   inflating: proCeleba/64/105323.jpg
#   inflating: proCeleba/64/081989.jpg
#   inflating: proCeleba/64/035592.jpg
#   inflating: proCeleba/64/004997.jpg
#   inflating: proCeleba/64/072801.jpg
#   inflating: proCeleba/64/117727.jpg
#   inflating: proCeleba/64/195056.jpg
#   inflating: proCeleba/64/091542.jpg
#   inflating: proCeleba/64/108607.jpg
#   inflating: proCeleba/64/202392.jpg
#   inflating: proCeleba/64/170964.jpg
#   inflating: proCeleba/64/183620.jpg
#   inflating: proCeleba/64/053603.jpg
#   inflating: proCeleba/64/148237.jpg
#   inflating: proCeleba/64/043410.jpg
#   inflating: proCeleba/64/097127.jpg
#   inflating: proCeleba/64/005445.jpg
#   inflating: proCeleba/64/147104.jpg
#   inflating: proCeleba/64/202386.jpg
#   inflating: proCeleba/64/051014.jpg
#   inflating: proCeleba/64/103746.jpg
#   inflating: proCeleba/64/083152.jpg
#   inflating: proCeleba/64/057465.jpg
#   inflating: proCeleba/64/180329.jpg
#   inflating: proCeleba/64/200591.jpg
#   inflating: proCeleba/64/047676.jpg
#   inflating: proCeleba/64/001623.jpg
#   inflating: proCeleba/64/154178.jpg
#   inflating: proCeleba/64/058030.jpg
#   inflating: proCeleba/64/011356.jpg
#   inflating: proCeleba/64/041561.jpg
#   inflating: proCeleba/64/092739.jpg
#   inflating: proCeleba/64/098572.jpg
#   inflating: proCeleba/64/101637.jpg
#   inflating: proCeleba/64/168681.jpg
#   inflating: proCeleba/64/005323.jpg
#   inflating: proCeleba/64/166874.jpg
#   inflating: proCeleba/64/158805.jpg
#   inflating: proCeleba/64/127009.jpg
#   inflating: proCeleba/64/097906.jpg
#   inflating: proCeleba/64/072034.jpg
#   inflating: proCeleba/64/176520.jpg
#   inflating: proCeleba/64/045698.jpg
#   inflating: proCeleba/64/063139.jpg
#   inflating: proCeleba/64/026465.jpg
#   inflating: proCeleba/64/038883.jpg
#   inflating: proCeleba/64/036676.jpg
#   inflating: proCeleba/64/037568.jpg
#   inflating: proCeleba/64/028448.jpg
#   inflating: proCeleba/64/020772.jpg
#   inflating: proCeleba/64/066727.jpg
#   inflating: proCeleba/64/036110.jpg
#   inflating: proCeleba/64/103801.jpg
#   inflating: proCeleba/64/040086.jpg
#   inflating: proCeleba/64/168078.jpg
#   inflating: proCeleba/64/035419.jpg
#   inflating: proCeleba/64/119859.jpg
#   inflating: proCeleba/64/063887.jpg
#   inflating: proCeleba/64/171529.jpg
#   inflating: proCeleba/64/183967.jpg
#   inflating: proCeleba/64/106979.jpg
#   inflating: proCeleba/64/119695.jpg
#   inflating: proCeleba/64/136676.jpg
#   inflating: proCeleba/64/073458.jpg
#   inflating: proCeleba/64/129756.jpg
#   inflating: proCeleba/64/156182.jpg
#   inflating: proCeleba/64/179161.jpg
#   inflating: proCeleba/64/089292.jpg
#   inflating: proCeleba/64/072746.jpg
#   inflating: proCeleba/64/140938.jpg
#   inflating: proCeleba/64/166041.jpg
#   inflating: proCeleba/64/050281.jpg
#   inflating: proCeleba/64/039237.jpg
#   inflating: proCeleba/64/060342.jpg
#   inflating: proCeleba/64/026317.jpg
#   inflating: proCeleba/64/142849.jpg
#   inflating: proCeleba/64/026471.jpg
#   inflating: proCeleba/64/077158.jpg
#   inflating: proCeleba/64/019681.jpg
#   inflating: proCeleba/64/083967.jpg
#   inflating: proCeleba/64/115911.jpg
#   inflating: proCeleba/64/006979.jpg
#   inflating: proCeleba/64/201062.jpg
#   inflating: proCeleba/64/056196.jpg
#   inflating: proCeleba/64/169414.jpg
#   inflating: proCeleba/64/166727.jpg
#   inflating: proCeleba/64/024266.jpg
#   inflating: proCeleba/64/158811.jpg
#   inflating: proCeleba/64/147931.jpg
#   inflating: proCeleba/64/072020.jpg
#   inflating: proCeleba/64/054781.jpg
#   inflating: proCeleba/64/139223.jpg
#   inflating: proCeleba/64/058193.jpg
#   inflating: proCeleba/64/077170.jpg
#   inflating: proCeleba/64/135431.jpg
#   inflating: proCeleba/64/006951.jpg
#   inflating: proCeleba/64/007497.jpg
#   inflating: proCeleba/64/019871.jpg
#   inflating: proCeleba/64/138115.jpg
#   inflating: proCeleba/64/072008.jpg
#   inflating: proCeleba/64/177602.jpg
#   inflating: proCeleba/64/129018.jpg
#   inflating: proCeleba/64/194599.jpg
#   inflating: proCeleba/64/111587.jpg
#   inflating: proCeleba/64/015093.jpg
#   inflating: proCeleba/64/178531.jpg
#   inflating: proCeleba/64/167411.jpg
#   inflating: proCeleba/64/168722.jpg
#   inflating: proCeleba/64/156814.jpg
#   inflating: proCeleba/64/097084.jpg
#   inflating: proCeleba/64/183783.jpg
#   inflating: proCeleba/64/128460.jpg
#   inflating: proCeleba/64/161706.jpg
#   inflating: proCeleba/64/117690.jpg
#   inflating: proCeleba/64/171515.jpg
#   inflating: proCeleba/64/028312.jpg
#   inflating: proCeleba/64/085480.jpg
#   inflating: proCeleba/64/038101.jpg
#   inflating: proCeleba/64/186823.jpg
#   inflating: proCeleba/64/020996.jpg
#   inflating: proCeleba/64/115087.jpg
#   inflating: proCeleba/64/181180.jpg
#   inflating: proCeleba/64/174479.jpg
#   inflating: proCeleba/64/049934.jpg
#   inflating: proCeleba/64/193584.jpg
#   inflating: proCeleba/64/087283.jpg
#   inflating: proCeleba/64/042861.jpg
#   inflating: proCeleba/64/128474.jpg
#   inflating: proCeleba/64/003183.jpg
#   inflating: proCeleba/64/090927.jpg
#   inflating: proCeleba/64/081194.jpg
#   inflating: proCeleba/64/034049.jpg
#   inflating: proCeleba/64/131643.jpg
#   inflating: proCeleba/64/073302.jpg
#   inflating: proCeleba/64/099903.jpg
#   inflating: proCeleba/64/015087.jpg
#   inflating: proCeleba/64/025144.jpg
#   inflating: proCeleba/64/063111.jpg
#   inflating: proCeleba/64/135425.jpg
#   inflating: proCeleba/64/031131.jpg
#   inflating: proCeleba/64/187297.jpg
#   inflating: proCeleba/64/067377.jpg
#   inflating: proCeleba/64/066069.jpg
#   inflating: proCeleba/64/059299.jpg
#   inflating: proCeleba/64/036886.jpg
#   inflating: proCeleba/64/196371.jpg
#   inflating: proCeleba/64/092665.jpg
#   inflating: proCeleba/64/163850.jpg
#   inflating: proCeleba/64/145129.jpg
#   inflating: proCeleba/64/144237.jpg
#   inflating: proCeleba/64/040723.jpg
#   inflating: proCeleba/64/094214.jpg
#   inflating: proCeleba/64/075940.jpg
#   inflating: proCeleba/64/140051.jpg
#   inflating: proCeleba/64/090072.jpg
#   inflating: proCeleba/64/054756.jpg
#   inflating: proCeleba/64/004161.jpg
#   inflating: proCeleba/64/117109.jpg
#   inflating: proCeleba/64/149713.jpg
#   inflating: proCeleba/64/108029.jpg
#   inflating: proCeleba/64/195678.jpg
#   inflating: proCeleba/64/052441.jpg
#   inflating: proCeleba/64/110100.jpg
#   inflating: proCeleba/64/156155.jpg
#   inflating: proCeleba/64/042652.jpg
#   inflating: proCeleba/64/099056.jpg
#   inflating: proCeleba/64/081619.jpg
#   inflating: proCeleba/64/119642.jpg
#   inflating: proCeleba/64/012065.jpg
#   inflating: proCeleba/64/087268.jpg
#   inflating: proCeleba/64/164681.jpg
#   inflating: proCeleba/64/068911.jpg
#   inflating: proCeleba/64/142120.jpg
#   inflating: proCeleba/64/051148.jpg
#   inflating: proCeleba/64/112703.jpg
#   inflating: proCeleba/64/175940.jpg
#   inflating: proCeleba/64/164695.jpg
#   inflating: proCeleba/64/011578.jpg
#   inflating: proCeleba/64/040051.jpg
#   inflating: proCeleba/64/006004.jpg
#   inflating: proCeleba/64/152327.jpg
#   inflating: proCeleba/64/082304.jpg
#   inflating: proCeleba/64/077825.jpg
#   inflating: proCeleba/64/182476.jpg
#   inflating: proCeleba/64/063850.jpg
#   inflating: proCeleba/64/100307.jpg
#   inflating: proCeleba/64/149061.jpg
#   inflating: proCeleba/64/062596.jpg
#   inflating: proCeleba/64/099042.jpg
#   inflating: proCeleba/64/119656.jpg
#   inflating: proCeleba/64/033901.jpg
#   inflating: proCeleba/64/194572.jpg
#   inflating: proCeleba/64/168911.jpg
#   inflating: proCeleba/64/086604.jpg
#   inflating: proCeleba/64/029959.jpg
#   inflating: proCeleba/64/066096.jpg
#   inflating: proCeleba/64/181619.jpg
#   inflating: proCeleba/64/189245.jpg
#   inflating: proCeleba/64/187268.jpg
#   inflating: proCeleba/64/190714.jpg
#   inflating: proCeleba/64/047058.jpg
#   inflating: proCeleba/64/053005.jpg
#   inflating: proCeleba/64/064871.jpg
#   inflating: proCeleba/64/022824.jpg
#   inflating: proCeleba/64/141373.jpg
#   inflating: proCeleba/64/168939.jpg
#   inflating: proCeleba/64/041401.jpg
#   inflating: proCeleba/64/191422.jpg
#   inflating: proCeleba/64/125839.jpg
#   inflating: proCeleba/64/007454.jpg
#   inflating: proCeleba/64/027784.jpg
#   inflating: proCeleba/64/070804.jpg
#   inflating: proCeleba/64/094228.jpg
#   inflating: proCeleba/64/078280.jpg
#   inflating: proCeleba/64/048343.jpg
#   inflating: proCeleba/64/001025.jpg
#   inflating: proCeleba/64/198406.jpg
#   inflating: proCeleba/64/125187.jpg
#   inflating: proCeleba/64/011550.jpg
#   inflating: proCeleba/64/083032.jpg
#   inflating: proCeleba/64/104149.jpg
#   inflating: proCeleba/64/018212.jpg
#   inflating: proCeleba/64/089279.jpg
#   inflating: proCeleba/64/148357.jpg
#   inflating: proCeleba/64/127948.jpg
#   inflating: proCeleba/64/108767.jpg
#   inflating: proCeleba/64/136851.jpg
#   inflating: proCeleba/64/170804.jpg
#   inflating: proCeleba/64/055306.jpg
#   inflating: proCeleba/64/136689.jpg
#   inflating: proCeleba/64/087240.jpg
#   inflating: proCeleba/64/183754.jpg
#   inflating: proCeleba/64/084749.jpg
#   inflating: proCeleba/64/047702.jpg
#   inflating: proCeleba/64/084991.jpg
#   inflating: proCeleba/64/181143.jpg
#   inflating: proCeleba/64/018206.jpg
#   inflating: proCeleba/64/145101.jpg
#   inflating: proCeleba/64/103154.jpg
#   inflating: proCeleba/64/038868.jpg
#   inflating: proCeleba/64/011222.jpg
#   inflating: proCeleba/64/200383.jpg
#   inflating: proCeleba/64/105525.jpg
#   inflating: proCeleba/64/088615.jpg
#   inflating: proCeleba/64/002538.jpg
#   inflating: proCeleba/64/111550.jpg
#   inflating: proCeleba/64/075968.jpg
#   inflating: proCeleba/64/183032.jpg
#   inflating: proCeleba/64/015044.jpg
#   inflating: proCeleba/64/099718.jpg
#   inflating: proCeleba/64/131858.jpg
#   inflating: proCeleba/64/141367.jpg
#   inflating: proCeleba/64/107332.jpg
#   inflating: proCeleba/64/120202.jpg
#   inflating: proCeleba/64/146187.jpg
#   inflating: proCeleba/64/042493.jpg
#   inflating: proCeleba/64/023079.jpg
#   inflating: proCeleba/64/178069.jpg
#   inflating: proCeleba/64/022367.jpg
#   inflating: proCeleba/64/025408.jpg
#   inflating: proCeleba/64/098189.jpg
#   inflating: proCeleba/64/074121.jpg
#   inflating: proCeleba/64/020570.jpg
#   inflating: proCeleba/64/162031.jpg
#   inflating: proCeleba/64/057920.jpg
#   inflating: proCeleba/64/050929.jpg
#   inflating: proCeleba/64/076050.jpg
#   inflating: proCeleba/64/143941.jpg
#   inflating: proCeleba/64/162757.jpg
#   inflating: proCeleba/64/199283.jpg
#   inflating: proCeleba/64/174135.jpg
#   inflating: proCeleba/64/009684.jpg
#   inflating: proCeleba/64/140290.jpg
#   inflating: proCeleba/64/055851.jpg
#   inflating: proCeleba/64/129226.jpg
#   inflating: proCeleba/64/126115.jpg
#   inflating: proCeleba/64/128138.jpg
#   inflating: proCeleba/64/176722.jpg
#   inflating: proCeleba/64/002909.jpg
#   inflating: proCeleba/64/024070.jpg
#   inflating: proCeleba/64/136312.jpg
#   inflating: proCeleba/64/032606.jpg
#   inflating: proCeleba/64/055845.jpg
#   inflating: proCeleba/64/177428.jpg
#   inflating: proCeleba/64/013810.jpg
#   inflating: proCeleba/64/130763.jpg
#   inflating: proCeleba/64/179405.jpg
#   inflating: proCeleba/64/033518.jpg
#   inflating: proCeleba/64/134505.jpg
#   inflating: proCeleba/64/016968.jpg
#   inflating: proCeleba/64/152680.jpg
#   inflating: proCeleba/64/143955.jpg
#   inflating: proCeleba/64/020202.jpg
#   inflating: proCeleba/64/199297.jpg
#   inflating: proCeleba/64/019483.jpg
#   inflating: proCeleba/64/026673.jpg
#   inflating: proCeleba/64/018945.jpg
#   inflating: proCeleba/64/060140.jpg
#   inflating: proCeleba/64/059919.jpg
#   inflating: proCeleba/64/174647.jpg
#   inflating: proCeleba/64/162025.jpg
#   inflating: proCeleba/64/066531.jpg
#   inflating: proCeleba/64/187917.jpg
#   inflating: proCeleba/64/034511.jpg
#   inflating: proCeleba/64/127579.jpg
#   inflating: proCeleba/64/052694.jpg
#   inflating: proCeleba/64/091807.jpg
#   inflating: proCeleba/64/043799.jpg
#   inflating: proCeleba/64/032160.jpg
#   inflating: proCeleba/64/011791.jpg
#   inflating: proCeleba/64/135155.jpg
#   inflating: proCeleba/64/031441.jpg
#   inflating: proCeleba/64/180088.jpg
#   inflating: proCeleba/64/067607.jpg
#   inflating: proCeleba/64/028110.jpg
#   inflating: proCeleba/64/013186.jpg
#   inflating: proCeleba/64/080922.jpg
#   inflating: proCeleba/64/177366.jpg
#   inflating: proCeleba/64/121120.jpg
#   inflating: proCeleba/64/012298.jpg
#   inflating: proCeleba/64/159925.jpg
#   inflating: proCeleba/64/121646.jpg
#   inflating: proCeleba/64/178733.jpg
#   inflating: proCeleba/64/100850.jpg
#   inflating: proCeleba/64/013838.jpg
#   inflating: proCeleba/64/023723.jpg
#   inflating: proCeleba/64/194943.jpg
#   inflating: proCeleba/64/050915.jpg
#   inflating: proCeleba/64/180936.jpg
#   inflating: proCeleba/64/175217.jpg
#   inflating: proCeleba/64/092498.jpg
#   inflating: proCeleba/64/201248.jpg
#   inflating: proCeleba/64/114825.jpg
#   inflating: proCeleba/64/029568.jpg
#   inflating: proCeleba/64/061504.jpg
#   inflating: proCeleba/64/050901.jpg
#   inflating: proCeleba/64/071717.jpg
#   inflating: proCeleba/64/196198.jpg
#   inflating: proCeleba/64/125434.jpg
#   inflating: proCeleba/64/067175.jpg
#   inflating: proCeleba/64/100844.jpg
#   inflating: proCeleba/64/131441.jpg
#   inflating: proCeleba/64/127223.jpg
#   inflating: proCeleba/64/023737.jpg
#   inflating: proCeleba/64/128110.jpg
#   inflating: proCeleba/64/171065.jpg
#   inflating: proCeleba/64/072578.jpg
#   inflating: proCeleba/64/178041.jpg
#   inflating: proCeleba/64/158391.jpg
#   inflating: proCeleba/64/173114.jpg
#   inflating: proCeleba/64/037024.jpg
#   inflating: proCeleba/64/094943.jpg
#   inflating: proCeleba/64/181382.jpg
#   inflating: proCeleba/64/123723.jpg
#   inflating: proCeleba/64/027237.jpg
#   inflating: proCeleba/64/046636.jpg
#   inflating: proCeleba/64/104377.jpg
#   inflating: proCeleba/64/142322.jpg
#   inflating: proCeleba/64/189735.jpg
#   inflating: proCeleba/64/186406.jpg
#   inflating: proCeleba/64/082112.jpg
#   inflating: proCeleba/64/030978.jpg
#   inflating: proCeleba/64/123910.jpg
#   inflating: proCeleba/64/019332.jpg
#   inflating: proCeleba/64/106560.jpg
#   inflating: proCeleba/64/109653.jpg
#   inflating: proCeleba/64/151438.jpg
#   inflating: proCeleba/64/073855.jpg
#   inflating: proCeleba/64/004405.jpg
#   inflating: proCeleba/64/014616.jpg
#   inflating: proCeleba/64/182660.jpg
#   inflating: proCeleba/64/086374.jpg
#   inflating: proCeleba/64/182106.jpg
#   inflating: proCeleba/64/156431.jpg
#   inflating: proCeleba/64/110464.jpg
#   inflating: proCeleba/64/150040.jpg
#   inflating: proCeleba/64/106206.jpg
#   inflating: proCeleba/64/039784.jpg
#   inflating: proCeleba/64/028851.jpg
#   inflating: proCeleba/64/006574.jpg
#   inflating: proCeleba/64/009647.jpg
#   inflating: proCeleba/64/056343.jpg
#   inflating: proCeleba/64/092467.jpg
#   inflating: proCeleba/64/060829.jpg
#   inflating: proCeleba/64/142444.jpg
#   inflating: proCeleba/64/112267.jpg
#   inflating: proCeleba/64/154232.jpg
#   inflating: proCeleba/64/048169.jpg
#   inflating: proCeleba/64/180705.jpg
#   inflating: proCeleba/64/197279.jpg
#   inflating: proCeleba/64/029583.jpg
#   inflating: proCeleba/64/144021.jpg
#   inflating: proCeleba/64/009653.jpg
#   inflating: proCeleba/64/018986.jpg
#   inflating: proCeleba/64/172593.jpg
#   inflating: proCeleba/64/039948.jpg
#   inflating: proCeleba/64/056357.jpg
#   inflating: proCeleba/64/186374.jpg
#   inflating: proCeleba/64/000111.jpg
#   inflating: proCeleba/64/026868.jpg
#   inflating: proCeleba/64/161289.jpg
#   inflating: proCeleba/64/004377.jpg
#   inflating: proCeleba/64/192301.jpg
#   inflating: proCeleba/64/080077.jpg
#   inflating: proCeleba/64/130978.jpg
#   inflating: proCeleba/64/184563.jpg
#   inflating: proCeleba/64/012273.jpg
#   inflating: proCeleba/64/073841.jpg
#   inflating: proCeleba/64/062794.jpg
#   inflating: proCeleba/64/035814.jpg
#   inflating: proCeleba/64/117479.jpg
#   inflating: proCeleba/64/176093.jpg
#   inflating: proCeleba/64/014602.jpg
#   inflating: proCeleba/64/165789.jpg
#   inflating: proCeleba/64/094764.jpg
#   inflating: proCeleba/64/016015.jpg
#   inflating: proCeleba/64/137959.jpg
#   inflating: proCeleba/64/015534.jpg
#   inflating: proCeleba/64/002048.jpg
#   inflating: proCeleba/64/147266.jpg
#   inflating: proCeleba/64/005727.jpg
#   inflating: proCeleba/64/043772.jpg
#   inflating: proCeleba/64/118762.jpg
#   inflating: proCeleba/64/159058.jpg
#   inflating: proCeleba/64/155662.jpg
#   inflating: proCeleba/64/174874.jpg
#   inflating: proCeleba/64/134288.jpg
#   inflating: proCeleba/64/103424.jpg
#   inflating: proCeleba/64/187724.jpg
#   inflating: proCeleba/64/153213.jpg
#   inflating: proCeleba/64/143000.jpg
#   inflating: proCeleba/64/165979.jpg
#   inflating: proCeleba/64/197251.jpg
#   inflating: proCeleba/64/047272.jpg
#   inflating: proCeleba/64/068291.jpg
#   inflating: proCeleba/64/200195.jpg
#   inflating: proCeleba/64/084239.jpg
#   inflating: proCeleba/64/027586.jpg
#   inflating: proCeleba/64/007656.jpg
#   inflating: proCeleba/64/133281.jpg
#   inflating: proCeleba/64/155104.jpg
#   inflating: proCeleba/64/032835.jpg
#   inflating: proCeleba/64/110458.jpg
#   inflating: proCeleba/64/013623.jpg
#   inflating: proCeleba/64/101555.jpg
#   inflating: proCeleba/64/121685.jpg
#   inflating: proCeleba/64/156419.jpg
#   inflating: proCeleba/64/034288.jpg
#   inflating: proCeleba/64/151376.jpg
#   inflating: proCeleba/64/097537.jpg
#   inflating: proCeleba/64/148627.jpg
#   inflating: proCeleba/64/015246.jpg
#   inflating: proCeleba/64/087724.jpg
#   inflating: proCeleba/64/158434.jpg
#   inflating: proCeleba/64/093751.jpg
#   inflating: proCeleba/64/200181.jpg
#   inflating: proCeleba/64/011020.jpg
#   inflating: proCeleba/64/187056.jpg
#   inflating: proCeleba/64/122398.jpg
#   inflating: proCeleba/64/037959.jpg
#   inflating: proCeleba/64/162964.jpg
#   inflating: proCeleba/64/008571.jpg
#   inflating: proCeleba/64/095320.jpg
#   inflating: proCeleba/64/059058.jpg
#   inflating: proCeleba/64/155110.jpg
#   inflating: proCeleba/64/051404.jpg
#   inflating: proCeleba/64/017337.jpg
#   inflating: proCeleba/64/174860.jpg
#   inflating: proCeleba/64/007124.jpg
#   inflating: proCeleba/64/048633.jpg
#   inflating: proCeleba/64/076905.jpg
#   inflating: proCeleba/64/126698.jpg
#   inflating: proCeleba/64/024925.jpg
#   inflating: proCeleba/64/005733.jpg
#   inflating: proCeleba/64/193745.jpg
#   inflating: proCeleba/64/126840.jpg
#   inflating: proCeleba/64/081433.jpg
#   inflating: proCeleba/64/183226.jpg
#   inflating: proCeleba/64/111744.jpg
#   inflating: proCeleba/64/158422.jpg
#   inflating: proCeleba/64/100649.jpg
#   inflating: proCeleba/64/151360.jpg
#   inflating: proCeleba/64/081343.jpg
#   inflating: proCeleba/64/026842.jpg
#   inflating: proCeleba/64/152669.jpg
#   inflating: proCeleba/64/123090.jpg
#   inflating: proCeleba/64/095336.jpg
#   inflating: proCeleba/64/145315.jpg
#   inflating: proCeleba/64/011036.jpg
#   inflating: proCeleba/64/078080.jpg
#   inflating: proCeleba/64/058350.jpg
#   inflating: proCeleba/64/082892.jpg
#   inflating: proCeleba/64/200197.jpg
#   inflating: proCeleba/64/016759.jpg
#   inflating: proCeleba/64/001543.jpg
#   inflating: proCeleba/64/143002.jpg
#   inflating: proCeleba/64/000885.jpg
#   inflating: proCeleba/64/069833.jpg
#   inflating: proCeleba/64/115244.jpg
#   inflating: proCeleba/64/095450.jpg
#   inflating: proCeleba/64/191144.jpg
#   inflating: proCeleba/64/181357.jpg
#   inflating: proCeleba/64/045301.jpg
#   inflating: proCeleba/64/091636.jpg
#   inflating: proCeleba/64/003354.jpg
#   inflating: proCeleba/64/096159.jpg
#   inflating: proCeleba/64/160803.jpg
#   inflating: proCeleba/64/185131.jpg
#   inflating: proCeleba/64/149249.jpg
#   inflating: proCeleba/64/147264.jpg
#   inflating: proCeleba/64/107898.jpg
#   inflating: proCeleba/64/111022.jpg
#   inflating: proCeleba/64/088367.jpg
#   inflating: proCeleba/64/110328.jpg
#   inflating: proCeleba/64/003340.jpg
#   inflating: proCeleba/64/091622.jpg
#   inflating: proCeleba/64/139962.jpg
#   inflating: proCeleba/64/005731.jpg
#   inflating: proCeleba/64/098160.jpg
#   inflating: proCeleba/64/087040.jpg
#   inflating: proCeleba/64/024927.jpg
#   inflating: proCeleba/64/143016.jpg
#   inflating: proCeleba/64/047502.jpg
#   inflating: proCeleba/64/021687.jpg
#   inflating: proCeleba/64/057711.jpg
#   inflating: proCeleba/64/069827.jpg
#   inflating: proCeleba/64/144779.jpg
#   inflating: proCeleba/64/132837.jpg
#   inflating: proCeleba/64/017335.jpg
#   inflating: proCeleba/64/113147.jpg
#   inflating: proCeleba/64/114628.jpg
#   inflating: proCeleba/64/007640.jpg
#   inflating: proCeleba/64/011022.jpg
#   inflating: proCeleba/64/190528.jpg
#   inflating: proCeleba/64/197247.jpg
#   inflating: proCeleba/64/047264.jpg
#   inflating: proCeleba/64/200183.jpg
#   inflating: proCeleba/64/088415.jpg
#   inflating: proCeleba/64/097535.jpg
#   inflating: proCeleba/64/176913.jpg
#   inflating: proCeleba/64/004349.jpg
#   inflating: proCeleba/64/099518.jpg
#   inflating: proCeleba/64/194996.jpg
#   inflating: proCeleba/64/074876.jpg
#   inflating: proCeleba/64/195450.jpg
#   inflating: proCeleba/64/173843.jpg
#   inflating: proCeleba/64/142446.jpg
#   inflating: proCeleba/64/010314.jpg
#   inflating: proCeleba/64/002710.jpg
#   inflating: proCeleba/64/140251.jpg
#   inflating: proCeleba/64/065953.jpg
#   inflating: proCeleba/64/074686.jpg
#   inflating: proCeleba/64/117309.jpg
#   inflating: proCeleba/64/156433.jpg
#   inflating: proCeleba/64/141629.jpg
#   inflating: proCeleba/64/086376.jpg
#   inflating: proCeleba/64/128847.jpg
#   inflating: proCeleba/64/137967.jpg
#   inflating: proCeleba/64/180075.jpg
#   inflating: proCeleba/64/123912.jpg
#   inflating: proCeleba/64/155884.jpg
#   inflating: proCeleba/64/115278.jpg
#   inflating: proCeleba/64/164481.jpg
#   inflating: proCeleba/64/152133.jpg
#   inflating: proCeleba/64/113609.jpg
#   inflating: proCeleba/64/016017.jpg
#   inflating: proCeleba/64/180061.jpg
#   inflating: proCeleba/64/123906.jpg
#   inflating: proCeleba/64/155890.jpg
#   inflating: proCeleba/64/006204.jpg
#   inflating: proCeleba/64/152127.jpg
#   inflating: proCeleba/64/082104.jpg
#   inflating: proCeleba/64/017309.jpg
#   inflating: proCeleba/64/175598.jpg
#   inflating: proCeleba/64/104361.jpg
#   inflating: proCeleba/64/000675.jpg
#   inflating: proCeleba/64/196603.jpg
#   inflating: proCeleba/64/043980.jpg
#   inflating: proCeleba/64/073843.jpg
#   inflating: proCeleba/64/184207.jpg
#   inflating: proCeleba/64/063488.jpg
#   inflating: proCeleba/64/109645.jpg
#   inflating: proCeleba/64/044751.jpg
#   inflating: proCeleba/64/157739.jpg
#   inflating: proCeleba/64/015278.jpg
#   inflating: proCeleba/64/065947.jpg
#   inflating: proCeleba/64/151348.jpg
#   inflating: proCeleba/64/091178.jpg
#   inflating: proCeleba/64/110472.jpg
#   inflating: proCeleba/64/181419.jpg
#   inflating: proCeleba/64/041629.jpg
#   inflating: proCeleba/64/144023.jpg
#   inflating: proCeleba/64/190514.jpg
#   inflating: proCeleba/64/006562.jpg
#   inflating: proCeleba/64/180707.jpg
#   inflating: proCeleba/64/093784.jpg
#   inflating: proCeleba/64/125422.jpg
#   inflating: proCeleba/64/021136.jpg
#   inflating: proCeleba/64/009862.jpg
#   inflating: proCeleba/64/061512.jpg
#   inflating: proCeleba/64/002937.jpg
#   inflating: proCeleba/64/111787.jpg
#   inflating: proCeleba/64/168522.jpg
#   inflating: proCeleba/64/136338.jpg
#   inflating: proCeleba/64/074679.jpg
#   inflating: proCeleba/64/063305.jpg
#   inflating: proCeleba/64/063463.jpg
#   inflating: proCeleba/64/167177.jpg
#   inflating: proCeleba/64/087097.jpg
#   inflating: proCeleba/64/178057.jpg
#   inflating: proCeleba/64/035625.jpg
#   inflating: proCeleba/64/033254.jpg
#   inflating: proCeleba/64/126895.jpg
#   inflating: proCeleba/64/071067.jpg
#   inflating: proCeleba/64/059933.jpg
#   inflating: proCeleba/64/021650.jpg
#   inflating: proCeleba/64/173102.jpg
#   inflating: proCeleba/64/191193.jpg
#   inflating: proCeleba/64/021644.jpg
#   inflating: proCeleba/64/125350.jpg
#   inflating: proCeleba/64/067611.jpg
#   inflating: proCeleba/64/196824.jpg
#   inflating: proCeleba/64/115293.jpg
#   inflating: proCeleba/64/173116.jpg
#   inflating: proCeleba/64/182851.jpg
#   inflating: proCeleba/64/025422.jpg
#   inflating: proCeleba/64/137754.jpg
#   inflating: proCeleba/64/033240.jpg
#   inflating: proCeleba/64/171701.jpg
#   inflating: proCeleba/64/062769.jpg
#   inflating: proCeleba/64/138467.jpg
#   inflating: proCeleba/64/169628.jpg
#   inflating: proCeleba/64/195493.jpg
#   inflating: proCeleba/64/146813.jpg
#   inflating: proCeleba/64/170379.jpg
#   inflating: proCeleba/64/101580.jpg
#   inflating: proCeleba/64/168536.jpg
#   inflating: proCeleba/64/159933.jpg
#   inflating: proCeleba/64/167605.jpg
#   inflating: proCeleba/64/058387.jpg
#   inflating: proCeleba/64/173670.jpg
#   inflating: proCeleba/64/021122.jpg
#   inflating: proCeleba/64/133254.jpg
#   inflating: proCeleba/64/017490.jpg
#   inflating: proCeleba/64/007683.jpg
#   inflating: proCeleba/64/028660.jpg
#   inflating: proCeleba/64/111963.jpg
#   inflating: proCeleba/64/169600.jpg
#   inflating: proCeleba/64/055853.jpg
#   inflating: proCeleba/64/160142.jpg
#   inflating: proCeleba/64/064456.jpg
#   inflating: proCeleba/64/121678.jpg
#   inflating: proCeleba/64/063339.jpg
#   inflating: proCeleba/64/089938.jpg
#   inflating: proCeleba/64/173658.jpg
#   inflating: proCeleba/64/122371.jpg
#   inflating: proCeleba/64/153588.jpg
#   inflating: proCeleba/64/191805.jpg
#   inflating: proCeleba/64/020214.jpg
#   inflating: proCeleba/64/173880.jpg
#   inflating: proCeleba/64/028648.jpg
#   inflating: proCeleba/64/189092.jpg
#   inflating: proCeleba/64/143943.jpg
#   inflating: proCeleba/64/105916.jpg
#   inflating: proCeleba/64/061248.jpg
#   inflating: proCeleba/64/123709.jpg
#   inflating: proCeleba/64/079407.jpg
#   inflating: proCeleba/64/174889.jpg
#   inflating: proCeleba/64/020572.jpg
#   inflating: proCeleba/64/066527.jpg
#   inflating: proCeleba/64/165984.jpg
#   inflating: proCeleba/64/141832.jpg
#   inflating: proCeleba/64/107867.jpg
#   inflating: proCeleba/64/139751.jpg
#   inflating: proCeleba/64/182879.jpg
#   inflating: proCeleba/64/129542.jpg
#   inflating: proCeleba/64/035619.jpg
#   inflating: proCeleba/64/022365.jpg
#   inflating: proCeleba/64/109692.jpg
#   inflating: proCeleba/64/126671.jpg
#   inflating: proCeleba/64/089086.jpg
#   inflating: proCeleba/64/099295.jpg
#   inflating: proCeleba/64/139745.jpg
#   inflating: proCeleba/64/128890.jpg
#   inflating: proCeleba/64/170423.jpg
#   inflating: proCeleba/64/074137.jpg
#   inflating: proCeleba/64/129556.jpg
#   inflating: proCeleba/64/064324.jpg
#   inflating: proCeleba/64/062755.jpg
#   inflating: proCeleba/64/024700.jpg
#   inflating: proCeleba/64/146191.jpg
#   inflating: proCeleba/64/172234.jpg
#   inflating: proCeleba/64/020566.jpg
#   inflating: proCeleba/64/069600.jpg
#   inflating: proCeleba/64/155853.jpg
#   inflating: proCeleba/64/085870.jpg
#   inflating: proCeleba/64/135619.jpg
#   inflating: proCeleba/64/029542.jpg
#   inflating: proCeleba/64/162999.jpg
#   inflating: proCeleba/64/009692.jpg
#   inflating: proCeleba/64/070437.jpg
#   inflating: proCeleba/64/142491.jpg
#   inflating: proCeleba/64/133268.jpg
#   inflating: proCeleba/64/076046.jpg
#   inflating: proCeleba/64/056396.jpg
#   inflating: proCeleba/64/062033.jpg
#   inflating: proCeleba/64/176734.jpg
#   inflating: proCeleba/64/141198.jpg
#   inflating: proCeleba/64/023709.jpg
#   inflating: proCeleba/64/161248.jpg
#   inflating: proCeleba/64/064442.jpg
#   inflating: proCeleba/64/074651.jpg
#   inflating: proCeleba/64/088165.jpg
#   inflating: proCeleba/64/111220.jpg
#   inflating: proCeleba/64/178296.jpg
#   inflating: proCeleba/64/106984.jpg
#   inflating: proCeleba/64/118562.jpg
#   inflating: proCeleba/64/141417.jpg
#   inflating: proCeleba/64/045103.jpg
#   inflating: proCeleba/64/023286.jpg
#   inflating: proCeleba/64/181155.jpg
#   inflating: proCeleba/64/084987.jpg
#   inflating: proCeleba/64/201935.jpg
#   inflating: proCeleba/64/021491.jpg
#   inflating: proCeleba/64/010894.jpg
#   inflating: proCeleba/64/093223.jpg
#   inflating: proCeleba/64/172963.jpg
#   inflating: proCeleba/64/143566.jpg
#   inflating: proCeleba/64/027786.jpg
#   inflating: proCeleba/64/036853.jpg
#   inflating: proCeleba/64/003630.jpg
#   inflating: proCeleba/64/107324.jpg
#   inflating: proCeleba/64/202582.jpg
#   inflating: proCeleba/64/081141.jpg
#   inflating: proCeleba/64/097723.jpg
#   inflating: proCeleba/64/141365.jpg
#   inflating: proCeleba/64/108003.jpg
#   inflating: proCeleba/64/055462.jpg
#   inflating: proCeleba/64/005255.jpg
#   inflating: proCeleba/64/131682.jpg
#   inflating: proCeleba/64/035396.jpg
#   inflating: proCeleba/64/111552.jpg
#   inflating: proCeleba/64/134922.jpg
#   inflating: proCeleba/64/200381.jpg
#   inflating: proCeleba/64/197045.jpg
#   inflating: proCeleba/64/188165.jpg
#   inflating: proCeleba/64/011220.jpg
#   inflating: proCeleba/64/078296.jpg
#   inflating: proCeleba/64/181627.jpg
#   inflating: proCeleba/64/199068.jpg
#   inflating: proCeleba/64/046378.jpg
#   inflating: proCeleba/64/017137.jpg
#   inflating: proCeleba/64/113423.jpg
#   inflating: proCeleba/64/164873.jpg
#   inflating: proCeleba/64/010658.jpg
#   inflating: proCeleba/64/187530.jpg
#   inflating: proCeleba/64/057513.jpg
#   inflating: proCeleba/64/009309.jpg
#   inflating: proCeleba/64/021485.jpg
#   inflating: proCeleba/64/178282.jpg
#   inflating: proCeleba/64/126498.jpg
#   inflating: proCeleba/64/015720.jpg
#   inflating: proCeleba/64/087242.jpg
#   inflating: proCeleba/64/148341.jpg
#   inflating: proCeleba/64/101027.jpg
#   inflating: proCeleba/64/013351.jpg
#   inflating: proCeleba/64/129973.jpg
#   inflating: proCeleba/64/100339.jpg
#   inflating: proCeleba/64/196415.jpg
#   inflating: proCeleba/64/152331.jpg
#   inflating: proCeleba/64/154740.jpg
#   inflating: proCeleba/64/016201.jpg
#   inflating: proCeleba/64/090716.jpg
#   inflating: proCeleba/64/127976.jpg
#   inflating: proCeleba/64/116573.jpg
#   inflating: proCeleba/64/139590.jpg
#   inflating: proCeleba/64/053985.jpg
#   inflating: proCeleba/64/100311.jpg
#   inflating: proCeleba/64/099054.jpg
#   inflating: proCeleba/64/182460.jpg
#   inflating: proCeleba/64/089247.jpg
#   inflating: proCeleba/64/072793.jpg
#   inflating: proCeleba/64/091408.jpg
#   inflating: proCeleba/64/168907.jpg
#   inflating: proCeleba/64/110664.jpg
#   inflating: proCeleba/64/086612.jpg
#   inflating: proCeleba/64/089521.jpg
#   inflating: proCeleba/64/146422.jpg
#   inflating: proCeleba/64/004163.jpg
#   inflating: proCeleba/64/150240.jpg
#   inflating: proCeleba/64/160383.jpg
#   inflating: proCeleba/64/140053.jpg
#   inflating: proCeleba/64/194564.jpg
#   inflating: proCeleba/64/112073.jpg
#   inflating: proCeleba/64/038842.jpg
#   inflating: proCeleba/64/189253.jpg
#   inflating: proCeleba/64/172787.jpg
#   inflating: proCeleba/64/142644.jpg
#   inflating: proCeleba/64/039590.jpg
#   inflating: proCeleba/64/006760.jpg
#   inflating: proCeleba/64/152443.jpg
#   inflating: proCeleba/64/125813.jpg
#   inflating: proCeleba/64/162580.jpg
#   inflating: proCeleba/64/110670.jpg
#   inflating: proCeleba/64/156625.jpg
#   inflating: proCeleba/64/054998.jpg
#   inflating: proCeleba/64/042122.jpg
#   inflating: proCeleba/64/096415.jpg
#   inflating: proCeleba/64/081169.jpg
#   inflating: proCeleba/64/045895.jpg
#   inflating: proCeleba/64/184763.jpg
#   inflating: proCeleba/64/109321.jpg
#   inflating: proCeleba/64/075956.jpg
#   inflating: proCeleba/64/140047.jpg
#   inflating: proCeleba/64/044553.jpg
#   inflating: proCeleba/64/109447.jpg
#   inflating: proCeleba/64/140721.jpg
#   inflating: proCeleba/64/129797.jpg
#   inflating: proCeleba/64/161937.jpg
#   inflating: proCeleba/64/193579.jpg
#   inflating: proCeleba/64/004611.jpg
#   inflating: proCeleba/64/072787.jpg
#   inflating: proCeleba/64/089253.jpg
#   inflating: proCeleba/64/049711.jpg
#   inflating: proCeleba/64/199732.jpg
#   inflating: proCeleba/64/186612.jpg
#   inflating: proCeleba/64/010664.jpg
#   inflating: proCeleba/64/145659.jpg
#   inflating: proCeleba/64/084777.jpg
#   inflating: proCeleba/64/077614.jpg
#   inflating: proCeleba/64/056802.jpg
#   inflating: proCeleba/64/066719.jpg
#   inflating: proCeleba/64/085482.jpg
#   inflating: proCeleba/64/117692.jpg
#   inflating: proCeleba/64/169358.jpg
#   inflating: proCeleba/64/107481.jpg
#   inflating: proCeleba/64/177166.jpg
#   inflating: proCeleba/64/148396.jpg
#   inflating: proCeleba/64/127989.jpg
#   inflating: proCeleba/64/101796.jpg
#   inflating: proCeleba/64/073314.jpg
#   inflating: proCeleba/64/064668.jpg
#   inflating: proCeleba/64/091391.jpg
#   inflating: proCeleba/64/012926.jpg
#   inflating: proCeleba/64/184950.jpg
#   inflating: proCeleba/64/172778.jpg
#   inflating: proCeleba/64/027745.jpg
#   inflating: proCeleba/64/036890.jpg
#   inflating: proCeleba/64/123251.jpg
#   inflating: proCeleba/64/021334.jpg
#   inflating: proCeleba/64/016598.jpg
#   inflating: proCeleba/64/048382.jpg
#   inflating: proCeleba/64/174309.jpg
#   inflating: proCeleba/64/029768.jpg
#   inflating: proCeleba/64/165210.jpg
#   inflating: proCeleba/64/197086.jpg
#   inflating: proCeleba/64/121452.jpg
#   inflating: proCeleba/64/179639.jpg
#   inflating: proCeleba/64/081196.jpg
#   inflating: proCeleba/64/004188.jpg
#   inflating: proCeleba/64/137230.jpg
#   inflating: proCeleba/64/090925.jpg
#   inflating: proCeleba/64/171503.jpg
#   inflating: proCeleba/64/072778.jpg
#   inflating: proCeleba/64/130239.jpg
#   inflating: proCeleba/64/035433.jpg
#   inflating: proCeleba/64/087281.jpg
#   inflating: proCeleba/64/004836.jpg
#   inflating: proCeleba/64/135341.jpg
#   inflating: proCeleba/64/164668.jpg
#   inflating: proCeleba/64/200424.jpg
#   inflating: proCeleba/64/067413.jpg
#   inflating: proCeleba/64/162219.jpg
#   inflating: proCeleba/64/181182.jpg
#   inflating: proCeleba/64/038117.jpg
#   inflating: proCeleba/64/028304.jpg
#   inflating: proCeleba/64/084950.jpg
#   inflating: proCeleba/64/062543.jpg
#   inflating: proCeleba/64/099097.jpg
#   inflating: proCeleba/64/160426.jpg
#   inflating: proCeleba/64/138895.jpg
#   inflating: proCeleba/64/117876.jpg
#   inflating: proCeleba/64/026301.jpg
#   inflating: proCeleba/64/154783.jpg
#   inflating: proCeleba/64/071259.jpg
#   inflating: proCeleba/64/079163.jpg
#   inflating: proCeleba/64/056180.jpg
#   inflating: proCeleba/64/163891.jpg
#   inflating: proCeleba/64/134711.jpg
#   inflating: proCeleba/64/046393.jpg
#   inflating: proCeleba/64/060432.jpg
#   inflating: proCeleba/64/150283.jpg
#   inflating: proCeleba/64/064654.jpg
#   inflating: proCeleba/64/147927.jpg
#   inflating: proCeleba/64/072036.jpg
#   inflating: proCeleba/64/158807.jpg
#   inflating: proCeleba/64/022615.jpg
#   inflating: proCeleba/64/062231.jpg
#   inflating: proCeleba/64/061738.jpg
#   inflating: proCeleba/64/163885.jpg
#   inflating: proCeleba/64/162543.jpg
#   inflating: proCeleba/64/047099.jpg
#   inflating: proCeleba/64/078269.jpg
#   inflating: proCeleba/64/181800.jpg
#   inflating: proCeleba/64/175981.jpg
#   inflating: proCeleba/64/122601.jpg
#   inflating: proCeleba/64/036106.jpg
#   inflating: proCeleba/64/174447.jpg
#   inflating: proCeleba/64/200418.jpg
#   inflating: proCeleba/64/103817.jpg
#   inflating: proCeleba/64/037218.jpg
#   inflating: proCeleba/64/124270.jpg
#   inflating: proCeleba/64/058807.jpg
#   inflating: proCeleba/64/197904.jpg
#   inflating: proCeleba/64/079611.jpg
#   inflating: proCeleba/64/047927.jpg
#   inflating: proCeleba/64/099083.jpg
#   inflating: proCeleba/64/129754.jpg
#   inflating: proCeleba/64/081814.jpg
#   inflating: proCeleba/64/043599.jpg
#   inflating: proCeleba/64/063649.jpg
#   inflating: proCeleba/64/195054.jpg
#   inflating: proCeleba/64/182528.jpg
#   inflating: proCeleba/64/151770.jpg
#   inflating: proCeleba/64/081753.jpg
#   inflating: proCeleba/64/100259.jpg
#   inflating: proCeleba/64/121297.jpg
#   inflating: proCeleba/64/101147.jpg
#   inflating: proCeleba/64/088011.jpg
#   inflating: proCeleba/64/015640.jpg
#   inflating: proCeleba/64/048553.jpg
#   inflating: proCeleba/64/068683.jpg
#   inflating: proCeleba/64/197643.jpg
#   inflating: proCeleba/64/020823.jpg
#   inflating: proCeleba/64/009269.jpg
#   inflating: proCeleba/64/191232.jpg
#   inflating: proCeleba/64/007244.jpg
#   inflating: proCeleba/64/145705.jpg
#   inflating: proCeleba/64/027194.jpg
#   inflating: proCeleba/64/181021.jpg
#   inflating: proCeleba/64/155270.jpg
#   inflating: proCeleba/64/059338.jpg
#   inflating: proCeleba/64/191554.jpg
#   inflating: proCeleba/64/188005.jpg
#   inflating: proCeleba/64/031090.jpg
#   inflating: proCeleba/64/102328.jpg
#   inflating: proCeleba/64/011340.jpg
#   inflating: proCeleba/64/153601.jpg
#   inflating: proCeleba/64/166862.jpg
#   inflating: proCeleba/64/150308.jpg
#   inflating: proCeleba/64/117043.jpg
#   inflating: proCeleba/64/022952.jpg
#   inflating: proCeleba/64/089469.jpg
#   inflating: proCeleba/64/195732.jpg
#   inflating: proCeleba/64/158740.jpg
#   inflating: proCeleba/64/194438.jpg
#   inflating: proCeleba/64/183144.jpg
#   inflating: proCeleba/64/179956.jpg
#   inflating: proCeleba/64/147660.jpg
#   inflating: proCeleba/64/192049.jpg
#   inflating: proCeleba/64/190886.jpg
#   inflating: proCeleba/64/181753.jpg
#   inflating: proCeleba/64/018416.jpg
#   inflating: proCeleba/64/095054.jpg
#   inflating: proCeleba/64/070966.jpg
#   inflating: proCeleba/64/188011.jpg
#   inflating: proCeleba/64/104995.jpg
#   inflating: proCeleba/64/125783.jpg
#   inflating: proCeleba/64/021297.jpg
#   inflating: proCeleba/64/019708.jpg
#   inflating: proCeleba/64/047112.jpg
#   inflating: proCeleba/64/200593.jpg
#   inflating: proCeleba/64/057467.jpg
#   inflating: proCeleba/64/011432.jpg
#   inflating: proCeleba/64/187444.jpg
#   inflating: proCeleba/64/103744.jpg
#   inflating: proCeleba/64/112891.jpg
#   inflating: proCeleba/64/027180.jpg
#   inflating: proCeleba/64/155502.jpg
#   inflating: proCeleba/64/069589.jpg
#   inflating: proCeleba/64/097125.jpg
#   inflating: proCeleba/64/101153.jpg
#   inflating: proCeleba/64/158026.jpg
#   inflating: proCeleba/64/196561.jpg
#   inflating: proCeleba/64/104003.jpg
#   inflating: proCeleba/64/110076.jpg
#   inflating: proCeleba/64/055258.jpg
#   inflating: proCeleba/64/119734.jpg
#   inflating: proCeleba/64/080471.jpg
#   inflating: proCeleba/64/012113.jpg
#   inflating: proCeleba/64/160591.jpg
#   inflating: proCeleba/64/140641.jpg
#   inflating: proCeleba/64/044355.jpg
#   inflating: proCeleba/64/033863.jpg
#   inflating: proCeleba/64/194410.jpg
#   inflating: proCeleba/64/119052.jpg
#   inflating: proCeleba/64/166686.jpg
#   inflating: proCeleba/64/149665.jpg
#   inflating: proCeleba/64/014204.jpg
#   inflating: proCeleba/64/147890.jpg
#   inflating: proCeleba/64/168873.jpg
#   inflating: proCeleba/64/072181.jpg
#   inflating: proCeleba/64/000271.jpg
#   inflating: proCeleba/64/186014.jpg
#   inflating: proCeleba/64/038936.jpg
#   inflating: proCeleba/64/197119.jpg
#   inflating: proCeleba/64/084171.jpg
#   inflating: proCeleba/64/050446.jpg
#   inflating: proCeleba/64/048209.jpg
#   inflating: proCeleba/64/104771.jpg
#   inflating: proCeleba/64/155258.jpg
#   inflating: proCeleba/64/152537.jpg
#   inflating: proCeleba/64/095068.jpg
#   inflating: proCeleba/64/164085.jpg
#   inflating: proCeleba/64/006614.jpg
#   inflating: proCeleba/64/093419.jpg
#   inflating: proCeleba/64/112113.jpg
#   inflating: proCeleba/64/084165.jpg
#   inflating: proCeleba/64/106166.jpg
#   inflating: proCeleba/64/119046.jpg
#   inflating: proCeleba/64/138088.jpg
#   inflating: proCeleba/64/156751.jpg
#   inflating: proCeleba/64/045739.jpg
#   inflating: proCeleba/64/107278.jpg
#   inflating: proCeleba/64/063926.jpg
#   inflating: proCeleba/64/089327.jpg
#   inflating: proCeleba/64/091568.jpg
#   inflating: proCeleba/64/100271.jpg
#   inflating: proCeleba/64/149117.jpg
#   inflating: proCeleba/64/151758.jpg
#   inflating: proCeleba/64/160585.jpg
#   inflating: proCeleba/64/109533.jpg
#   inflating: proCeleba/64/194362.jpg
#   inflating: proCeleba/64/151980.jpg
#   inflating: proCeleba/64/154620.jpg
#   inflating: proCeleba/64/039382.jpg
#   inflating: proCeleba/64/084603.jpg
#   inflating: proCeleba/64/009241.jpg
#   inflating: proCeleba/64/175836.jpg
#   inflating: proCeleba/64/094410.jpg
#   inflating: proCeleba/64/006172.jpg
#   inflating: proCeleba/64/082272.jpg
#   inflating: proCeleba/64/056745.jpg
#   inflating: proCeleba/64/076495.jpg
#   inflating: proCeleba/64/046556.jpg
#   inflating: proCeleba/64/000503.jpg
#   inflating: proCeleba/64/162392.jpg
#   inflating: proCeleba/64/028264.jpg
#   inflating: proCeleba/64/112846.jpg
#   inflating: proCeleba/64/027157.jpg
#   inflating: proCeleba/64/068898.jpg
#   inflating: proCeleba/64/200544.jpg
#   inflating: proCeleba/64/010923.jpg
#   inflating: proCeleba/64/068640.jpg
#   inflating: proCeleba/64/093394.jpg
#   inflating: proCeleba/64/049856.jpg
#   inflating: proCeleba/64/083187.jpg
#   inflating: proCeleba/64/129608.jpg
#   inflating: proCeleba/64/004956.jpg
#   inflating: proCeleba/64/015683.jpg
#   inflating: proCeleba/64/128516.jpg
#   inflating: proCeleba/64/127625.jpg
#   inflating: proCeleba/64/023331.jpg
#   inflating: proCeleba/64/110089.jpg
#   inflating: proCeleba/64/023457.jpg
#   inflating: proCeleba/64/035235.jpg
#   inflating: proCeleba/64/087487.jpg
#   inflating: proCeleba/64/183193.jpg
#   inflating: proCeleba/64/195929.jpg
#   inflating: proCeleba/64/063073.jpg
#   inflating: proCeleba/64/167567.jpg
#   inflating: proCeleba/64/193380.jpg
#   inflating: proCeleba/64/110937.jpg
#   inflating: proCeleba/64/092934.jpg
#   inflating: proCeleba/64/125754.jpg
#   inflating: proCeleba/64/134881.jpg
#   inflating: proCeleba/64/070769.jpg
#   inflating: proCeleba/64/181784.jpg
#   inflating: proCeleba/64/028502.jpg
#   inflating: proCeleba/64/011397.jpg
#   inflating: proCeleba/64/163715.jpg
#   inflating: proCeleba/64/134895.jpg
#   inflating: proCeleba/64/200236.jpg
#   inflating: proCeleba/64/125740.jpg
#   inflating: proCeleba/64/174269.jpg
#   inflating: proCeleba/64/190845.jpg
#   inflating: proCeleba/64/019913.jpg
#   inflating: proCeleba/64/061670.jpg
#   inflating: proCeleba/64/138077.jpg
#   inflating: proCeleba/64/003793.jpg
#   inflating: proCeleba/64/097858.jpg
#   inflating: proCeleba/64/065416.jpg
#   inflating: proCeleba/64/182299.jpg
#   inflating: proCeleba/64/073274.jpg
#   inflating: proCeleba/64/149856.jpg
#   inflating: proCeleba/64/110923.jpg
#   inflating: proCeleba/64/156976.jpg
#   inflating: proCeleba/64/131053.jpg
#   inflating: proCeleba/64/042917.jpg
#   inflating: proCeleba/64/195083.jpg
#   inflating: proCeleba/64/065370.jpg
#   inflating: proCeleba/64/014589.jpg
#   inflating: proCeleba/64/202347.jpg
#   inflating: proCeleba/64/183839.jpg
#   inflating: proCeleba/64/171477.jpg
#   inflating: proCeleba/64/123457.jpg
#   inflating: proCeleba/64/186799.jpg
#   inflating: proCeleba/64/017080.jpg
#   inflating: proCeleba/64/200550.jpg
#   inflating: proCeleba/64/058797.jpg
#   inflating: proCeleba/64/173260.jpg
#   inflating: proCeleba/64/054185.jpg
#   inflating: proCeleba/64/126507.jpg
#   inflating: proCeleba/64/117902.jpg
#   inflating: proCeleba/64/081974.jpg
#   inflating: proCeleba/64/138739.jpg
#   inflating: proCeleba/64/090879.jpg
#   inflating: proCeleba/64/062437.jpg
#   inflating: proCeleba/64/008188.jpg
#   inflating: proCeleba/64/046581.jpg
#   inflating: proCeleba/64/069562.jpg
#   inflating: proCeleba/64/058967.jpg
#   inflating: proCeleba/64/019085.jpg
#   inflating: proCeleba/64/036066.jpg
#   inflating: proCeleba/64/145922.jpg
#   inflating: proCeleba/64/066889.jpg
#   inflating: proCeleba/64/092908.jpg
#   inflating: proCeleba/64/202409.jpg
#   inflating: proCeleba/64/064720.jpg
#   inflating: proCeleba/64/035209.jpg
#   inflating: proCeleba/64/088788.jpg
#   inflating: proCeleba/64/170027.jpg
#   inflating: proCeleba/64/169562.jpg
#   inflating: proCeleba/64/075639.jpg
#   inflating: proCeleba/64/024310.jpg
#   inflating: proCeleba/64/052286.jpg
#   inflating: proCeleba/64/179771.jpg
#   inflating: proCeleba/64/034103.jpg
#   inflating: proCeleba/64/130417.jpg
#   inflating: proCeleba/64/126275.jpg
#   inflating: proCeleba/64/160220.jpg
#   inflating: proCeleba/64/139355.jpg
#   inflating: proCeleba/64/003977.jpg
#   inflating: proCeleba/64/181974.jpg
#   inflating: proCeleba/64/051957.jpg
#   inflating: proCeleba/64/153832.jpg
#   inflating: proCeleba/64/124462.jpg
#   inflating: proCeleba/64/070999.jpg
#   inflating: proCeleba/64/084818.jpg
#   inflating: proCeleba/64/189496.jpg
#   inflating: proCeleba/64/036072.jpg
#   inflating: proCeleba/64/019091.jpg
#   inflating: proCeleba/64/057498.jpg
#   inflating: proCeleba/64/029152.jpg
#   inflating: proCeleba/64/135209.jpg
# ...
#   inflating: proCeleba/64/193437.jpg
#   inflating: proCeleba/64/148233.jpg
#   inflating: proCeleba/64/054168.jpg
#   inflating: proCeleba/64/096229.jpg
#   inflating: proCeleba/64/185241.jpg
#   inflating: proCeleba/64/091546.jpg
#   inflating: proCeleba/64/088017.jpg
#   inflating: proCeleba/64/158034.jpg
#   inflating: proCeleba/64/138918.jpg
#   inflating: proCeleba/64/101141.jpg
#   inflating: proCeleba/64/005455.jpg
#   inflating: proCeleba/64/034850.jpg
#   inflating: proCeleba/64/122798.jpg
#   inflating: proCeleba/64/153161.jpg
#   inflating: proCeleba/64/011420.jpg
#   inflating: proCeleba/64/057475.jpg
#   inflating: proCeleba/64/175818.jpg
#   inflating: proCeleba/64/040109.jpg
#   inflating: proCeleba/64/186990.jpg
#   inflating: proCeleba/64/200581.jpg
#   inflating: proCeleba/64/164915.jpg
#   inflating: proCeleba/64/037381.jpg
#   inflating: proCeleba/64/113545.jpg
#   inflating: proCeleba/64/095720.jpg
#   inflating: proCeleba/64/018404.jpg
#   inflating: proCeleba/64/092729.jpg
#   inflating: proCeleba/64/198210.jpg
#   inflating: proCeleba/64/057313.jpg
#   inflating: proCeleba/64/115652.jpg
#   inflating: proCeleba/64/094358.jpg
#   inflating: proCeleba/64/015120.jpg
#   inflating: proCeleba/64/053175.jpg
#   inflating: proCeleba/64/033859.jpg
#   inflating: proCeleba/64/166864.jpg
#   inflating: proCeleba/64/091220.jpg
#   inflating: proCeleba/64/118376.jpg
#   inflating: proCeleba/64/033681.jpg
#   inflating: proCeleba/64/013551.jpg
#   inflating: proCeleba/64/024316.jpg
#   inflating: proCeleba/64/039421.jpg
#   inflating: proCeleba/64/070747.jpg
#   inflating: proCeleba/64/181972.jpg
#   inflating: proCeleba/64/029632.jpg
#   inflating: proCeleba/64/026501.jpg
#   inflating: proCeleba/64/030363.jpg
#   inflating: proCeleba/64/079005.jpg
#   inflating: proCeleba/64/019929.jpg
#   inflating: proCeleba/64/020170.jpg
#   inflating: proCeleba/64/153834.jpg
#   inflating: proCeleba/64/069216.jpg
#   inflating: proCeleba/64/162357.jpg
#   inflating: proCeleba/64/018389.jpg
#   inflating: proCeleba/64/056780.jpg
#   inflating: proCeleba/64/026267.jpg
#   inflating: proCeleba/64/009284.jpg
#   inflating: proCeleba/64/126515.jpg
#   inflating: proCeleba/64/032212.jpg
#   inflating: proCeleba/64/108830.jpg
#   inflating: proCeleba/64/183803.jpg
#   inflating: proCeleba/64/176322.jpg
#   inflating: proCeleba/64/151951.jpg
#   inflating: proCeleba/64/150497.jpg
#   inflating: proCeleba/64/053834.jpg
#   inflating: proCeleba/64/033118.jpg
#   inflating: proCeleba/64/169216.jpg
#   inflating: proCeleba/64/179005.jpg
#   inflating: proCeleba/64/030411.jpg
#   inflating: proCeleba/64/047841.jpg
#   inflating: proCeleba/64/164732.jpg
#   inflating: proCeleba/64/009290.jpg
#   inflating: proCeleba/64/122767.jpg
#   inflating: proCeleba/64/154197.jpg
#   inflating: proCeleba/64/008830.jpg
#   inflating: proCeleba/64/036706.jpg
#   inflating: proCeleba/64/060540.jpg
#   inflating: proCeleba/64/028538.jpg
#   inflating: proCeleba/64/069202.jpg
#   inflating: proCeleba/64/065438.jpg
#   inflating: proCeleba/64/042087.jpg
#   inflating: proCeleba/64/121508.jpg
#   inflating: proCeleba/64/003965.jpg
#   inflating: proCeleba/64/063049.jpg
#   inflating: proCeleba/64/045930.jpg
#   inflating: proCeleba/64/139347.jpg
#   inflating: proCeleba/64/119097.jpg
#   inflating: proCeleba/64/068134.jpg
#   inflating: proCeleba/64/001182.jpg
#   inflating: proCeleba/64/078327.jpg
#   inflating: proCeleba/64/095091.jpg
#   inflating: proCeleba/64/127151.jpg
#   inflating: proCeleba/64/054815.jpg
#   inflating: proCeleba/64/003795.jpg
#   inflating: proCeleba/64/169558.jpg
#   inflating: proCeleba/64/032548.jpg
#   inflating: proCeleba/64/168646.jpg
#   inflating: proCeleba/64/167575.jpg
#   inflating: proCeleba/64/073272.jpg
#   inflating: proCeleba/64/015691.jpg
#   inflating: proCeleba/64/126529.jpg
#   inflating: proCeleba/64/075165.jpg
#   inflating: proCeleba/64/119901.jpg
#   inflating: proCeleba/64/038065.jpg
#   inflating: proCeleba/64/154801.jpg
#   inflating: proCeleba/64/031727.jpg
#   inflating: proCeleba/64/174509.jpg
#   inflating: proCeleba/64/125020.jpg
#   inflating: proCeleba/64/067561.jpg
#   inflating: proCeleba/64/133656.jpg
#   inflating: proCeleba/64/038071.jpg
#   inflating: proCeleba/64/031733.jpg
#   inflating: proCeleba/64/035555.jpg
#   inflating: proCeleba/64/101182.jpg
#   inflating: proCeleba/64/167207.jpg
#   inflating: proCeleba/64/065362.jpg
#   inflating: proCeleba/64/202433.jpg
#   inflating: proCeleba/64/171303.jpg
#   inflating: proCeleba/64/179987.jpg
#   inflating: proCeleba/64/177772.jpg
#   inflating: proCeleba/64/129168.jpg
#   inflating: proCeleba/64/158791.jpg
#   inflating: proCeleba/64/039409.jpg
#   inflating: proCeleba/64/021246.jpg
#   inflating: proCeleba/64/078333.jpg
#   inflating: proCeleba/64/031055.jpg
#   inflating: proCeleba/64/173514.jpg
#   inflating: proCeleba/64/085296.jpg
#   inflating: proCeleba/64/040874.jpg
#   inflating: proCeleba/64/046752.jpg
#   inflating: proCeleba/64/163288.jpg
#   inflating: proCeleba/64/069969.jpg
#   inflating: proCeleba/64/094614.jpg
#   inflating: proCeleba/64/193609.jpg
#   inflating: proCeleba/64/116617.jpg
#   inflating: proCeleba/64/080661.jpg
#   inflating: proCeleba/64/014772.jpg
#   inflating: proCeleba/64/062182.jpg
#   inflating: proCeleba/64/110500.jpg
#   inflating: proCeleba/64/074938.jpg
#   inflating: proCeleba/64/141029.jpg
#   inflating: proCeleba/64/194600.jpg
#   inflating: proCeleba/64/115478.jpg
#   inflating: proCeleba/64/070586.jpg
#   inflating: proCeleba/64/041983.jpg
#   inflating: proCeleba/64/026918.jpg
#   inflating: proCeleba/64/153439.jpg
#   inflating: proCeleba/64/071854.jpg
#   inflating: proCeleba/64/060781.jpg
#   inflating: proCeleba/64/011178.jpg
#   inflating: proCeleba/64/190472.jpg
#   inflating: proCeleba/64/084375.jpg
#   inflating: proCeleba/64/199330.jpg
#   inflating: proCeleba/64/155048.jpg
#   inflating: proCeleba/64/010266.jpg
#   inflating: proCeleba/64/056233.jpg
#   inflating: proCeleba/64/082704.jpg
#   inflating: proCeleba/64/146752.jpg
#   inflating: proCeleba/64/192265.jpg
#   inflating: proCeleba/64/062196.jpg
#   inflating: proCeleba/64/014000.jpg
#   inflating: proCeleba/64/045529.jpg
#   inflating: proCeleba/64/129395.jpg
#   inflating: proCeleba/64/194614.jpg
#   inflating: proCeleba/64/150130.jpg
#   inflating: proCeleba/64/119530.jpg
#   inflating: proCeleba/64/170586.jpg
#   inflating: proCeleba/64/012317.jpg
#   inflating: proCeleba/64/148019.jpg
#   inflating: proCeleba/64/146034.jpg
#   inflating: proCeleba/64/200967.jpg
#   inflating: proCeleba/64/142252.jpg
#   inflating: proCeleba/64/199456.jpg
#   inflating: proCeleba/64/123860.jpg
#   inflating: proCeleba/64/105119.jpg
#   inflating: proCeleba/64/029381.jpg
#   inflating: proCeleba/64/043616.jpg
#   inflating: proCeleba/64/005643.jpg
#   inflating: proCeleba/64/158222.jpg
#   inflating: proCeleba/64/044179.jpg
#   inflating: proCeleba/64/151560.jpg
#   inflating: proCeleba/64/055074.jpg
#   inflating: proCeleba/64/118606.jpg
#   inflating: proCeleba/64/174910.jpg
#   inflating: proCeleba/64/051212.jpg
#   inflating: proCeleba/64/037197.jpg
#   inflating: proCeleba/64/036289.jpg
#   inflating: proCeleba/64/105131.jpg
#   inflating: proCeleba/64/123848.jpg
#   inflating: proCeleba/64/197453.jpg
#   inflating: proCeleba/64/143164.jpg
#   inflating: proCeleba/64/011636.jpg
#   inflating: proCeleba/64/078680.jpg
#   inflating: proCeleba/64/124841.jpg
#   inflating: proCeleba/64/162814.jpg
#   inflating: proCeleba/64/021093.jpg
#   inflating: proCeleba/64/197335.jpg
#   inflating: proCeleba/64/085043.jpg
#   inflating: proCeleba/64/104549.jpg
#   inflating: proCeleba/64/145273.jpg
#   inflating: proCeleba/64/033497.jpg
#   inflating: proCeleba/64/141015.jpg
#   inflating: proCeleba/64/121939.jpg
#   inflating: proCeleba/64/090328.jpg
#   inflating: proCeleba/64/015336.jpg
#   inflating: proCeleba/64/127384.jpg
#   inflating: proCeleba/64/052069.jpg
#   inflating: proCeleba/64/194628.jpg
#   inflating: proCeleba/64/178680.jpg
#   inflating: proCeleba/64/157663.jpg
#   inflating: proCeleba/64/130820.jpg
#   inflating: proCeleba/64/115450.jpg
#   inflating: proCeleba/64/198012.jpg
#   inflating: proCeleba/64/021087.jpg
#   inflating: proCeleba/64/093635.jpg
#   inflating: proCeleba/64/020399.jpg
#   inflating: proCeleba/64/180885.jpg
#   inflating: proCeleba/64/008415.jpg
#   inflating: proCeleba/64/008373.jpg
#   inflating: proCeleba/64/051206.jpg
#   inflating: proCeleba/64/113747.jpg
#   inflating: proCeleba/64/017253.jpg
#   inflating: proCeleba/64/069799.jpg
#   inflating: proCeleba/64/059882.jpg
#   inflating: proCeleba/64/050118.jpg
#   inflating: proCeleba/64/132789.jpg
#   inflating: proCeleba/64/197447.jpg
#   inflating: proCeleba/64/001431.jpg
#   inflating: proCeleba/64/093153.jpg
#   inflating: proCeleba/64/165809.jpg
#   inflating: proCeleba/64/190328.jpg
#   inflating: proCeleba/64/121093.jpg
#   inflating: proCeleba/64/043602.jpg
#   inflating: proCeleba/64/157105.jpg
#   inflating: proCeleba/64/003226.jpg
#   inflating: proCeleba/64/055060.jpg
#   inflating: proCeleba/64/004549.jpg
#   inflating: proCeleba/64/127409.jpg
#   inflating: proCeleba/64/005864.jpg
#   inflating: proCeleba/64/043831.jpg
#   inflating: proCeleba/64/072434.jpg
#   inflating: proCeleba/64/034461.jpg
#   inflating: proCeleba/64/138529.jpg
#   inflating: proCeleba/64/074045.jpg
#   inflating: proCeleba/64/107901.jpg
#   inflating: proCeleba/64/044186.jpg
#   inflating: proCeleba/64/140492.jpg
#   inflating: proCeleba/64/046949.jpg
#   inflating: proCeleba/64/172346.jpg
#   inflating: proCeleba/64/011811.jpg
#   inflating: proCeleba/64/102879.jpg
#   inflating: proCeleba/64/201476.jpg
#   inflating: proCeleba/64/143825.jpg
#   inflating: proCeleba/64/061448.jpg
#   inflating: proCeleba/64/029430.jpg
#   inflating: proCeleba/64/070545.jpg
#   inflating: proCeleba/64/191963.jpg
#   inflating: proCeleba/64/039623.jpg
#   inflating: proCeleba/64/129342.jpg
#   inflating: proCeleba/64/013960.jpg
#   inflating: proCeleba/64/130613.jpg
#   inflating: proCeleba/64/160030.jpg
#   inflating: proCeleba/64/055921.jpg
#   inflating: proCeleba/64/129356.jpg
#   inflating: proCeleba/64/024100.jpg
#   inflating: proCeleba/64/201304.jpg
#   inflating: proCeleba/64/143831.jpg
#   inflating: proCeleba/64/018821.jpg
#   inflating: proCeleba/64/132010.jpg
#   inflating: proCeleba/64/021078.jpg
#   inflating: proCeleba/64/154395.jpg
#   inflating: proCeleba/64/009092.jpg
#   inflating: proCeleba/64/048970.jpg
#   inflating: proCeleba/64/161448.jpg
#   inflating: proCeleba/64/150695.jpg
#   inflating: proCeleba/64/044192.jpg
#   inflating: proCeleba/64/031525.jpg
#   inflating: proCeleba/64/006389.jpg
#   inflating: proCeleba/64/123653.jpg
#   inflating: proCeleba/64/005858.jpg
#   inflating: proCeleba/64/127435.jpg
#   inflating: proCeleba/64/052900.jpg
#   inflating: proCeleba/64/178131.jpg
#   inflating: proCeleba/64/015493.jpg
#   inflating: proCeleba/64/063263.jpg
#   inflating: proCeleba/64/044804.jpg
#   inflating: proCeleba/64/171115.jpg
#   inflating: proCeleba/64/023647.jpg
#   inflating: proCeleba/64/085080.jpg
#   inflating: proCeleba/64/038501.jpg
#   inflating: proCeleba/64/037632.jpg
#   inflating: proCeleba/64/133326.jpg
#   inflating: proCeleba/64/077216.jpg
#   inflating: proCeleba/64/124882.jpg
#   inflating: proCeleba/64/135757.jpg
#   inflating: proCeleba/64/115487.jpg
#   inflating: proCeleba/64/125544.jpg
#   inflating: proCeleba/64/163511.jpg
#   inflating: proCeleba/64/105694.jpg
#   inflating: proCeleba/64/009910.jpg
#   inflating: proCeleba/64/061460.jpg
#   inflating: proCeleba/64/078131.jpg
#   inflating: proCeleba/64/131525.jpg
#   inflating: proCeleba/64/183397.jpg
#   inflating: proCeleba/64/121736.jpg
#   inflating: proCeleba/64/117284.jpg
#   inflating: proCeleba/64/033440.jpg
#   inflating: proCeleba/64/081594.jpg
#   inflating: proCeleba/64/109904.jpg
#   inflating: proCeleba/64/107929.jpg
#   inflating: proCeleba/64/063511.jpg
#   inflating: proCeleba/64/170579.jpg
#   inflating: proCeleba/64/052914.jpg
#   inflating: proCeleba/64/015487.jpg
#   inflating: proCeleba/64/118809.jpg
#   inflating: proCeleba/64/021722.jpg
#   inflating: proCeleba/64/124128.jpg
#   inflating: proCeleba/64/094827.jpg
#   inflating: proCeleba/64/071115.jpg
#   inflating: proCeleba/64/161313.jpg
#   inflating: proCeleba/64/107096.jpg
#   inflating: proCeleba/64/128075.jpg
#   inflating: proCeleba/64/148959.jpg
#   inflating: proCeleba/64/137155.jpg
#   inflating: proCeleba/64/062168.jpg
#   inflating: proCeleba/64/063276.jpg
#   inflating: proCeleba/64/178642.jpg
#   inflating: proCeleba/64/100921.jpg
#   inflating: proCeleba/64/073065.jpg
#   inflating: proCeleba/64/174078.jpg
#   inflating: proCeleba/64/001395.jpg
#   inflating: proCeleba/64/021045.jpg
#   inflating: proCeleba/64/067010.jpg
#   inflating: proCeleba/64/061461.jpg
#   inflating: proCeleba/64/016831.jpg
#   inflating: proCeleba/64/133333.jpg
#   inflating: proCeleba/64/175366.jpg
#   inflating: proCeleba/64/175400.jpg
#   inflating: proCeleba/64/124129.jpg
#   inflating: proCeleba/64/113785.jpg
#   inflating: proCeleba/64/123646.jpg
#   inflating: proCeleba/64/135024.jpg
#   inflating: proCeleba/64/077565.jpg
#   inflating: proCeleba/64/031530.jpg
#   inflating: proCeleba/64/200741.jpg
#   inflating: proCeleba/64/048795.jpg
#   inflating: proCeleba/64/073703.jpg
#   inflating: proCeleba/64/035756.jpg
#   inflating: proCeleba/64/182936.jpg
#   inflating: proCeleba/64/202156.jpg
#   inflating: proCeleba/64/177203.jpg
#   inflating: proCeleba/64/121045.jpg
#   inflating: proCeleba/64/063504.jpg
#   inflating: proCeleba/64/023120.jpg
#   inflating: proCeleba/64/091792.jpg
#   inflating: proCeleba/64/078642.jpg
#   inflating: proCeleba/64/135030.jpg
#   inflating: proCeleba/64/048781.jpg
#   inflating: proCeleba/64/132039.jpg
#   inflating: proCeleba/64/125545.jpg
#   inflating: proCeleba/64/135756.jpg
#   inflating: proCeleba/64/124883.jpg
#   inflating: proCeleba/64/061475.jpg
#   inflating: proCeleba/64/114798.jpg
#   inflating: proCeleba/64/076109.jpg
#   inflating: proCeleba/64/016825.jpg
#   inflating: proCeleba/64/134448.jpg
#   inflating: proCeleba/64/037633.jpg
#   inflating: proCeleba/64/071666.jpg
#   inflating: proCeleba/64/065613.jpg
#   inflating: proCeleba/64/128061.jpg
#   inflating: proCeleba/64/138272.jpg
#   inflating: proCeleba/64/044805.jpg
#   inflating: proCeleba/64/194826.jpg
#   inflating: proCeleba/64/025237.jpg
#   inflating: proCeleba/64/159840.jpg
#   inflating: proCeleba/64/055908.jpg
#   inflating: proCeleba/64/040493.jpg
#   inflating: proCeleba/64/071896.jpg
#   inflating: proCeleba/64/134460.jpg
#   inflating: proCeleba/64/076121.jpg
#   inflating: proCeleba/64/093813.jpg
#   inflating: proCeleba/64/038528.jpg
#   inflating: proCeleba/64/124673.jpg
#   inflating: proCeleba/64/162626.jpg
#   inflating: proCeleba/64/069001.jpg
#   inflating: proCeleba/64/052097.jpg
#   inflating: proCeleba/64/074736.jpg
#   inflating: proCeleba/64/109087.jpg
#   inflating: proCeleba/64/126064.jpg
#   inflating: proCeleba/64/053389.jpg
#   inflating: proCeleba/64/129431.jpg
#   inflating: proCeleba/64/178118.jpg
#   inflating: proCeleba/64/118834.jpg
#   inflating: proCeleba/64/054380.jpg
#   inflating: proCeleba/64/169015.jpg
#   inflating: proCeleba/64/116819.jpg
#   inflating: proCeleba/64/124115.jpg
#   inflating: proCeleba/64/187872.jpg
#   inflating: proCeleba/64/046784.jpg
#   inflating: proCeleba/64/077559.jpg
#   inflating: proCeleba/64/085917.jpg
#   inflating: proCeleba/64/198946.jpg
#   inflating: proCeleba/64/189693.jpg
#   inflating: proCeleba/64/009087.jpg
#   inflating: proCeleba/64/026064.jpg
#   inflating: proCeleba/64/132763.jpg
#   inflating: proCeleba/64/019294.jpg
#   inflating: proCeleba/64/136505.jpg
#   inflating: proCeleba/64/130174.jpg
#   inflating: proCeleba/64/150858.jpg
#   inflating: proCeleba/64/072353.jpg

# %% [markdown]
# ### Import libraries

# %%
from tqdm import tqdm

from torch.autograd import Variable, grad
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image
import os
import torch as t
import torch.nn as nn
from torchvision import datasets, transforms, utils
from torch.utils.data import Dataset, DataLoader
from skimage import io
import copy

# %% [markdown]
# ### Set initial hyperparameters

# %%
batch_size = 64

resolution = 16

img_fold_dir_64_reso = f"/content/proCeleba/{resolution}"

iteration = 200

critic = 5          

eval_size = 25

laten_space = 100

device = t.device('cuda' if t.cuda.is_available() else 'cpu')

log_folder = "log"
# !mkdir "log"
# !mkdir "log/checkpoint"
# !mkdir "log/sample"

# %% [markdown]
# ### Show me which gpu I am using.

# %%
# !nvidia-smi -L

# %% [markdown]
# ### Pre loading the data

# %%
# Define a data class for load unclassfied data.
class Get_No_Classes_Img_Dataset(Dataset):
    
    def __init__(self, folder_dir, transform = None):
        self.folder_dir = os.path.join(folder_dir)
        self.transform = transform
        self.image_list = os.listdir(self.folder_dir)
        
    def __len__(self):
        return len(os.listdir(self.folder_dir))
    
    def __getitem__(self, index):
        
        image_name = self.image_list[index]
        
        image_dir = os.path.join(self.folder_dir, image_name)
        
        image = io.imread(image_dir)
        
        if (self.transform != None):
            image = self.transform(image)
        
        return image
    

transform = transforms.Compose([
    transforms.ToTensor()       #From Batch * Highth * Width * Channel to Batch * Channel * Highth * Width
                                  #Which is what pytorch CNN can work with.
]) 

dataset = Get_No_Classes_Img_Dataset(img_fold_dir_64_reso, transform = transform) 
                                                            # datasets[0].shape = (16,16,3)
                                                            # len(datasets) = 28000
total_data_len = len(dataset)
                                                                                            
#datasets_batched = DataLoader(datasets, batch_size = batch_size) #loader is renewed every epoch

# %% [markdown]
# ```
# loader = iter(loader)
# print(next(loader).shape)
# ```
# will output
#
#
# ```
# torch.Size([batch_size, 3, resolution, resolution])
# ```
#
# So data loading is ready.
#
# What's left is keep using
#
# ```
# next(loader)
# ```
# to access each batch of data

# %% [markdown]
# ### Visualize a picture

# %%
from IPython.display import Image, display




# Viewing one data sample function:
def showOneImge(img, i, shouldSave):
    
    img = img.squeeze()
    
    img = transforms.ToPILImage()(img)
    
    plt.figure(figsize = (10,10), dpi = 10)
    plt.axis('off')
    
    if shouldSave:
      saveDir = f'{log_folder}/sample/{str(i).zfill(6)}.png'
      plt.imshow(img)
      plt.savefig(saveDir, bbox_inches='tight', pad_inches = 0)
      img = Image(saveDir)
      display(img)
    else:
      deleteDir = f"{log_folder}/sample/Delete.png"
      plt.imshow(img)
      plt.savefig(deleteDir, bbox_inches='tight', pad_inches = 0)
      img = Image(deleteDir)
      display(img)
      # !rm "/content/log/sample/Delete.png"
    return 

''' Testing showOneImage'''
# loader = DataLoader(datasets, batch_size = batch_size)

# data = iter(loader)

# oneSample = next(data)[0]

# showOneImge(oneSample, 9999, True)


def showMoreImages(img, num):

  subplot_x = int(num ** (1/2))
  subplot_y = num // subplot_x
  plt.figure(figsize = (2,2))
  for i in range(len(img)):
      aimg = transforms.ToPILImage()(img[i])
      plt.subplot(subplot_x, subplot_y, i+1)
      plt.imshow(aimg)
      plt.axis('off')

# %% [markdown]
# -------------------------------------------------
#
# ### Now Designing the simple GAN network

# %%
"""
Define the generator
"""

class G(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.laten = nn.Sequential(
            nn.Linear(laten_space, 100),
            nn.Linear(100, 500),
            nn.Linear(500, 128 * resolution * resolution))

        self.model = nn.Sequential(
            nn.Conv2d(128, 64, (3, 3), padding = "same"),
            nn.LeakyReLU(0.2),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 32, (3, 3), padding = "same"),
            nn.LeakyReLU(0.2),
            nn.Dropout2d(),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 3, (3, 3), padding = "same"),
            nn.Sigmoid()
        )
        
        
        
    def forward(self, theInput, batch_size):
        
        x = self.laten(theInput)
        
        x = t.reshape(x, (batch_size, 128, resolution, resolution))
         
        x = self.model(x)
            
            
        return x
    
class D(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.netWork = nn.Sequential(
            nn.Conv2d(3, 64, (3, 3), padding = "same"),
            nn.LeakyReLU(),
            nn.Dropout2d(0.3),
            nn.Conv2d(64, 128, (3, 3), stride = (3, 3)),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(),
            nn.Conv2d(128, 1, (3, 3), stride = (3, 3)),
            nn.Flatten())
        
    def forward(self, theInput):
        
        return self.netWork(theInput)

# %% [markdown]
# ### Testing the network

# %%
"""

Testing the net work:

"""

# oneImg = next(iter(datasets))[0]

# showOneImge(oneImg, 0)

# oneImg = oneImg.expand(1,3,64,64)

# print(oneImg.shape)

# print(oneImg)

# #img into G to test shape

# input_noise_example = t.randn((batch_size, 1, 1, 5))

# a = G()(input_noise_example, batch_size)
# print(a[0])
# showOneImge(a[0], 0)

# b = D()(next(loader))

# print(b.shape)

# %% [markdown]
# ### Gradient Penalty from wGAN.

# %%
def compute_gradient_penalty(D, real_samples, fake_samples, current_batch_size):
    """Calculates the gradient penalty loss for WGAN GP"""
    # Random weight term for interpolation between real and fake samples
    alpha = t.randn((current_batch_size, 1, 1, 1)).to(device)
    # Get random interpolation between real and fake samples
    interpolates = (alpha * real_samples + ((1 - alpha) * fake_samples)).requires_grad_(True)
    
    
    d_interpolates = D(interpolates)
    
    
    grad_x_hat = grad(
            outputs=d_interpolates.sum(), inputs=interpolates, create_graph=True)[0]
    grad_penalty = ((grad_x_hat.view(grad_x_hat.size(0), -1)
                      .norm(2, dim=1) - 1)**2).mean()
    grad_penalty = 10 * grad_penalty
    
    return grad_penalty

# %% [markdown]
# ### Try FID LOSS

# %%
import cupy as np
from torchvision.models.feature_extraction import create_feature_extractor
from torchvision.models.feature_extraction import get_graph_node_names

import scipy.linalg as linalg


class FID_Loss(nn.Module):
  def __init__(self):
    super().__init__()
    self.model = t.hub.load('pytorch/vision:v0.10.0', 'inception_v3', pretrained=True)

    self.model.eval()

    self.model = create_feature_extractor(self.model, {'avgpool': 'feat'})


  def sqrtm(self, a):
    # Computing diagonalization
        evalues, evectors = np.linalg.eigh(a)
        # Ensuring square root matrix exists
        #assert (evalues >= 0).all()
        covmean = evectors @ np.diag(np.sqrt(evalues)) @ np.linalg.inv(evectors)
        return covmean

  # calculate frechet inception distance
  # A faster FID calculation modified from https://github.com/mseitzer/pytorch-fid/blob/master/src/pytorch_fid/fid_score.py
  def calculate_frechet_distance(self, ac1, ac2, eps=1e-6):
      """Numpy implementation of the Frechet Distance.
      The Frechet distance between two multivariate Gaussians X_1 ~ N(mu_1, C_1)
      and X_2 ~ N(mu_2, C_2) is
              d^2 = ||mu_1 - mu_2||^2 + Tr(C_1 + C_2 - 2*sqrt(C_1*C_2)).
      Stable version by Dougal J. Sutherland.
      Params:
      -- mu1   : Numpy array containing the activations of a layer of the
                inception net (like returned by the function 'get_predictions')
                for generated samples.
      -- mu2   : The sample mean over activations, precalculated on an
                representative data set.
      -- sigma1: The covariance matrix over activations for generated samples.
      -- sigma2: The covariance matrix over activations, precalculated on an
                representative data set.
      Returns:
      --   : The Frechet Distance.
      """
      
      print("ac1: ", ac1.shape)

      with np.cuda.Device(0):
      
        ac1 = np.array(ac1.cpu().detach().numpy())
        ac2 = np.array(ac2.cpu().detach().numpy())


        mu1 = np.mean(ac1)
        sigma1 = np.cov(ac1)
        
        mu2 = np.mean(ac2)
        sigma2 = np.cov(ac2)

        mu1 = np.atleast_1d(mu1)
        mu2 = np.atleast_1d(mu2)

        sigma1 = np.atleast_2d(sigma1)
        sigma2 = np.atleast_2d(sigma2)

        assert mu1.shape == mu2.shape, \
            'Training and test mean vectors have different lengths'
        assert sigma1.shape == sigma2.shape, \
            'Training and test covariances have different dimensions'

        diff = mu1 - mu2

        # Product might be almost singular
        print("sigma1 shape: ", sigma1.shape)
        print("sigma2 shape: ", sigma2.shape)


        # Computing diagonalization
        covmean = self.sqrtm(sigma1.T@sigma2)
        #covmean, _ = linalg.sqrtm(sigma1@sigma2.T, disp=False)
        print(covmean.shape)
        if not np.isfinite(covmean).all():
            msg = ('fid calculation produces singular product; '
                  'adding %s to diagonal of cov estimates') % eps
            print(msg)
            offset = np.eye(sigma1.shape[0]) * eps
            covmean = self.sqrtm((sigma1 + offset).dot(sigma2 + offset))

        # Numerical error might give slight imaginary component
        if np.iscomplexobj(covmean):
            if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
                m = np.max(np.abs(covmean.imag))
                raise ValueError('Imaginary component {}'.format(m))
            covmean = covmean.real

        tr_covmean = np.trace(covmean)

        return  100 * (diff.dot(diff) + np.trace(sigma1)
                + np.trace(sigma2) - 2 * tr_covmean)
      



  def forward(self, fake, real):

    with t.no_grad():
    
      upsamle_layer = t.nn.UpsamplingBilinear2d(size=299)

      transform = transforms.Compose([
                                    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
      ])

      fake = upsamle_layer(fake)
      fake = transform(fake)

      fake_feature = self.model(fake)['feat']
      fake_feature = fake_feature.reshape((fake_feature.shape[0], 2048))

      real = upsamle_layer(real)
      real = transform(real)

      real_feature = self.model(real)['feat']
      real_feature = real_feature.reshape((real_feature.shape[0], 2048))
      print("real_feature: ", real_feature.shape)
      FID_score = self.calculate_frechet_distance(real_feature, fake_feature)

    return FID_score


FID_loss = FID_Loss().to(device)

# %%
"Testing FID Loss"
fake = t.randn((64, 3, 16, 16)).to(device)
real = t.randn((64, 3, 16, 16)).to(device)

#same = FID_loss(fake, fake)

dif = FID_loss(fake, real)

dif = dif.reshape((1,1))

dif = t.from_numpy(dif)

a = nn.Sequential(
    nn.Linear(1, 10),
    nn.Linear(10, 1)
)

a_opt = t.optim.Adam(a.parameters(), lr = 0.001)

loss = a(dif.float())

loss.backward()

print(a.state_dict())


print("same: ", same)
print("dif", dif)

# %% [markdown]
# ### Initializing the generator, discriminator, optimizer, labels, and loss.

# %%
generator = G().to(device)
discriminator = D().to(device)

G_optimizer = t.optim.Adam(generator.parameters(), lr = 0.00001)
D_optimizer = t.optim.Adam(discriminator.parameters(), lr = 0.00001)

label_real = t.ones((batch_size, 1)).to(device)
label_fake = t.zeros((batch_size, 1)).to(device)

# %% [markdown]
# ### Train decider

# %%
for i in range(iteration):

    p = tqdm(range(total_data_len // batch_size + 1)) # This is a progress bar run on each epoch
    
    datasets_batched = DataLoader(dataset, batch_size = batch_size)
    
    loader = iter(datasets_batched)

    for j in p:
        

        batchNum = str(i+1)
        
        #Training the D
        #real data
        real = next(loader).to(device)

        #current_batch size (the last batch is different than others)
        current_batch_size, c, h, w = real.shape
        #labels
        label_real = 0.1 * t.randint(7,10,(current_batch_size,1)).type(t.half)
        label_fake = 0.1 * t.randint(0,3,(current_batch_size,1)).type(t.half)

        real_score = discriminator(real)
        d_real_loss = -t.mean(real_score)
        
        input_noise = t.normal(0, 1, size = (current_batch_size, 1, 1, laten_space)).to(device)
        fake = generator(input_noise, current_batch_size)
        fake_score = discriminator(fake)

        d_fake_loss = t.mean(fake_score)

        gradient_penalty = compute_gradient_penalty(discriminator, real, fake, current_batch_size)
        
        total_loss = -FID_loss(real, fake)

        generator.zero_grad()
        discriminator.zero_grad()
        total_loss.backward()
        D_optimizer.step()





        if j % critic == 0:
          input_noise = t.normal(0, 1, size = (current_batch_size, 1, 1, laten_space)).to(device)
          fake = generator(input_noise, current_batch_size)
          fake_score = discriminator(fake)
          g_fake_loss = -t.mean(fake_score)
          discriminator.zero_grad()
          generator.zero_grad()
          g_fake_loss.backward()
          G_optimizer.step()

          

        
        mse = "Epoch: " + batchNum
        
        p.set_description(mse)
            
        p.set_postfix(G_loss = g_fake_loss.item(), D_total_loss = total_loss.item(), real_score = real_score.mean().item(), fake_score = fake_score.mean().item())
        
    if i == 0:
        showOneImge(real[0], 99999, True)   
    
    if i % 2 == 0:
      
      showOneImge(real[0], 99999, False)
      showOneImge(fake[0], i, False)
      print("epoch = ", i + 1)  
      print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'.format(i, iteration, j+1, total_data_len // batch_size + 1, total_loss.item(), g_fake_loss.item(), real_score.mean().item(), fake_score.mean().item()))      
      

    if i % 50 == 0:
      t.save(generator.state_dict(), f'{log_folder}/checkpoint/{str(i + 1).zfill(6)}_g.model')
      t.save(discriminator.state_dict(), f'{log_folder}/checkpoint/{str(i + 1).zfill(6)}_d.model')
# Out:
#   0%|          | 0/438 [00:00<?, ?it/s]
# real_feature:  torch.Size([64, 2048])
# ac1:  torch.Size([64, 2048])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-82f94c22397b> in <module>()
#      33         gradient_penalty = compute_gradient_penalty(discriminator, real, fake, current_batch_size)
#      34
# ---> 35         total_loss = -FID_loss(real, fake)
#      36
#      37         generator.zero_grad()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-15-9b2682eeedb2> in forward(self, fake, real)
#     111       real_feature = real_feature.reshape((real_feature.shape[0], 2048))
#     112       print("real_feature: ", real_feature.shape)
# --> 113       FID_score = self.calculate_frechet_distance(real_feature, fake_feature)
#     114
#     115     return FID_score
#
# <ipython-input-15-9b2682eeedb2> in calculate_frechet_distance(self, ac1, ac2, eps)
#      40       print("ac1: ", ac1.shape)
#      41
# ---> 42       ac1 = np.array(ac1.get())
#      43       ac2 = np.array(ac2.get())
#      44
#
# AttributeError: 'Tensor' object has no attribute 'get'

# %% [markdown]
# ### Show Result

# %%
#Generated
generator.eval()

with t.no_grad():
  input_noise = t.normal(0, 1, size = (eval_size, 1, 1, laten_space)).to(device)
  generated = generator(input_noise, eval_size)
  showMoreImages(generated, eval_size)

#Real
datasets_batched = DataLoader(dataset, batch_size = eval_size)
loader = iter(datasets_batched)
real = next(loader)
showMoreImages(real, eval_size)

# %% [markdown]
# ### remove log file when necessarry

# %%
# !rm -rf /content/log/checkpoint

# !mkdir /content/log/checkpoint

# !rm -rf /content/log/sample
# !mkdir /content/log/sample

# from google.colab import files
# files.download('/content/log')
